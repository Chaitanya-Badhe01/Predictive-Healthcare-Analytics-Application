# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import pickle
import json
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("diabetes_data_upload.csv")
df.sample(10)
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 123   47    Male       No        Yes                 No       No         No
# 424   43    Male      Yes        Yes                Yes      Yes         No
# 237   65    Male       No         No                 No      Yes         No
# 187   72    Male      Yes         No                Yes      Yes        Yes
# 9     70    Male       No        Yes                Yes      Yes        Yes
# 353   60    Male       No         No                 No      Yes         No
# 414   55  Female      Yes        Yes                Yes      Yes         No
# 477   40    Male       No         No                Yes       No         No
# 310   67    Male      Yes         No                 No      Yes        Yes
# 443   35    Male      Yes         No                Yes       No         No
#
#     Genital thrush visual blurring Itching Irritability delayed healing  \
# 123             No             Yes     Yes           No              No
# 424            Yes              No      No           No              No
# 237             No             Yes     Yes           No             Yes
# 187             No              No      No          Yes             Yes
# 9               No             Yes     Yes          Yes              No
# 353             No              No      No           No              No
# 414             No             Yes      No           No              No
# 477             No              No      No           No              No
# 310             No             Yes     Yes          Yes             Yes
# 443             No              No      No           No              No
#
#     partial paresis muscle stiffness Alopecia Obesity     class
# 123              No               No      Yes     Yes  Positive
# 424              No               No       No      No  Positive
# 237             Yes              Yes      Yes      No  Negative
# 187             Yes              Yes      Yes      No  Positive
# 9                No               No      Yes      No  Positive
# 353             Yes              Yes       No      No  Negative
# 414             Yes               No       No     Yes  Positive
# 477              No               No       No     Yes  Negative
# 310              No              Yes      Yes     Yes  Negative
# 443             Yes               No      Yes      No  Positive

# %%
df.iloc[313]
# Out:
# Age                         54
# Gender                    Male
# Polyuria                    No
# Polydipsia                  No
# sudden weight loss         Yes
# weakness                   Yes
# Polyphagia                  No
# Genital thrush             Yes
# visual blurring             No
# Itching                     No
# Irritability                No
# delayed healing            Yes
# partial paresis             No
# muscle stiffness            No
# Alopecia                   Yes
# Obesity                     No
# class                 Negative
# Name: 313, dtype: object

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'class'],
#       dtype='object')

# %%
X = df.drop('class', axis=1)
y = df['class']

# %%
X['Gender'].replace(['Male', 'Female'], [1, 0], inplace=True)
X['Polyuria'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Polydipsia'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['sudden weight loss'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['weakness'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Polyphagia'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Genital thrush'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['visual blurring'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Itching'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Irritability'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['delayed healing'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['partial paresis'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['muscle stiffness'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Alopecia'].replace(['Yes', 'No'], [1, 0], inplace=True)
X['Obesity'].replace(['Yes', 'No'], [1, 0], inplace=True)
# Out:
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Gender'].replace(['Male', 'Female'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Gender'].replace(['Male', 'Female'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Polyuria'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Polyuria'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Polydipsia'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Polydipsia'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['sudden weight loss'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['sudden weight loss'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['weakness'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['weakness'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Polyphagia'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Polyphagia'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Genital thrush'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Genital thrush'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['visual blurring'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['visual blurring'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Itching'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Itching'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Irritability'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Irritability'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['delayed healing'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['delayed healing'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['partial paresis'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['partial paresis'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['muscle stiffness'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['muscle stiffness'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Alopecia'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Alopecia'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Obesity'].replace(['Yes', 'No'], [1, 0], inplace=True)
# C:\Users\nikam\AppData\Local\Temp\ipykernel_19632\3350313514.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Obesity'].replace(['Yes', 'No'], [1, 0], inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=True,random_state=4, stratify=y)

# %%
y_train
# Out:
# 469    Negative
# 66     Positive
# 494    Negative
# 506    Negative
# 312    Negative
#          ...
# 518    Negative
# 411    Negative
# 507    Negative
# 49     Positive
# 359    Positive
# Name: class, Length: 468, dtype: object

# %%
clf = RandomForestClassifier()
clf.fit(X_train.values, y_train)
y_pred_train = clf.predict(X_train.values)
y_pred = clf.predict(X_test.values)
y_acc = accuracy_score(y_test, y_pred)
y_acc_train = accuracy_score(y_train, y_pred_train)
print(y_acc_train)
print(y_acc)
# Out:
# 1.0
# 1.0

# %%
import pickle
pickle.dump(clf, open('diabetes_model.pkl', 'wb'))

# %%
model = pickle.load(open('diabetes_model.pkl', 'rb'))

# %%
print(model.predict([[54, 1, 0, 0, 1, 1, 0, 1, 0, 0, 0, 1, 0, 0, 1, 0]]))
# Out:
# ['Negative']
